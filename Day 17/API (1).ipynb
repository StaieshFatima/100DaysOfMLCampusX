# %%
import pandas as pd
import requests

# %% [markdown]
# ### **To send request**

# %%
requests.get('https://jsonplaceholder.typicode.com/posts')
# Out:
# <Response [200]>

# %%
url='https://api.themoviedb.org/3/movie/11'

# %%
api_key='apikey here'

# %%
response=requests.get(url,params={"api_key":api_key})

# %% [markdown]
# ### **To check status**

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### **To see data**

# %%
data=response.json()
data
# Out:
# {'adult': False,
#  'backdrop_path': '/zqkmTXzjkAgXmEWLRsY4UpTWCeo.jpg',
#  'belongs_to_collection': {'id': 10,
#   'name': 'Star Wars Collection',
#   'poster_path': '/pWVLFh4OuejTpUaDQbB1C4zoS2p.jpg',
#   'backdrop_path': '/iY2ujEY2m68OTTlPFTiHub9joHS.jpg'},
#  'budget': 11000000,
#  'genres': [{'id': 12, 'name': 'Adventure'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.starwars.com/films/star-wars-episode-iv-a-new-hope',
#  'id': 11,
#  'imdb_id': 'tt0076759',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Star Wars',
#  'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.',
#  'popularity': 36.234,
# ...

# %%
df=pd.DataFrame([data])
df
# Out:
#    adult                     backdrop_path  \
# 0  False  /zqkmTXzjkAgXmEWLRsY4UpTWCeo.jpg
#
#                                belongs_to_collection    budget  \
# 0  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                             homepage  id    imdb_id  \
# 0  http://www.starwars.com/films/star-wars-episod...  11  tt0076759
#
#   origin_country original_language  ...    revenue runtime  softcore  \
# 0           [US]                en  ...  775398007     121     False
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                         tagline      title  video  \
# 0  A long time ago in a galaxy far, far away...  Star Wars  False
#
#    vote_average  vote_count
# 0         8.207       22902
#
# [1 rows x 27 columns]

# %%
df=pd.DataFrame([data])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
df
# Out:
#    id      title                                           overview  \
# 0  11  Star Wars  Princess Leia is captured and held hostage by ...
#
#   release_date  popularity  vote_average  vote_count
# 0   1977-05-25      36.234         8.207       22902

# %% [markdown]
# ## **Doing all this work in loop**

# %%
url = "https://api.themoviedb.org/3/movie/top_rated"

# %%
api_key='api_key here'

# %%
response=requests.get(url,params={"api_key":api_key})
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
data=response.json()
data
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/caBIySpwuFi2i7ynvHIlnxJLOdN.jpg',
#    'genre_ids': [16, 28, 12, 878],
#    'id': 1560520,
#    'title': 'Batman: Knightfall Part 1: Knightfall',
#    'original_language': 'en',
#    'original_title': 'Batman: Knightfall Part 1: Knightfall',
#    'overview': 'Arkham Asylum has been destroyed, and all its inmates have been unleashed upon Gotham City. As Batman races to round up some of his greatest enemies, he is pushed to his physical and mental limits and into a final confrontation with a new threat: the man called Bane!',
#    'popularity': 75.0853,
#    'poster_path': '/360qdtu2hLnqMu8SVHMywn420w1.jpg',
#    'release_date': '2026-06-23',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.16,
#    'vote_count': 373},
#   {'adult': False,
#    'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#    'genre_ids': [16, 12, 14, 28],
#    'id': 980431,
#    'title': 'Avatar Aang: The Last Airbender',
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/caBIySpwuF...          562
# 1      1  {'adult': False, 'backdrop_path': '/ezbrL1dMym...          562
# 2      1  {'adult': False, 'backdrop_path': '/zMwhWailP1...          562
# 3      1  {'adult': False, 'backdrop_path': '/iCML6fBe3X...          562
# 4      1  {'adult': False, 'backdrop_path': '/1RgPyOhN4D...          562
# 5      1  {'adult': False, 'backdrop_path': '/c4U96GrPRf...          562
# 6      1  {'adult': False, 'backdrop_path': '/pNjh59JSxC...          562
# 7      1  {'adult': False, 'backdrop_path': '/tSPT36ZKlP...          562
# 8      1  {'adult': False, 'backdrop_path': '/8Tfys3mDZV...          562
# 9      1  {'adult': False, 'backdrop_path': '/ufSwlnECLo...          562
# 10     1  {'adult': False, 'backdrop_path': '/3HaqAPZ0C8...          562
# 11     1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          562
# ...

# %%
df=pd.DataFrame(data['results'])[['id','title','overview','release_date']]
df
# Out:
#          id                                           title  \
# 0   1560520           Batman: Knightfall Part 1: Knightfall
# 1    980431                 Avatar Aang: The Last Airbender
# 2   1007757                                         Swapped
# 3   1632181                             Accidental Partners
# 4   1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# 5   1621552                                 Facing El Chapo
# 6       278                        The Shawshank Redemption
# 7       238                                   The Godfather
# 8    687163                               Project Hail Mary
# 9    936075                                         Michael
# 10  1232449                                    Young Hearts
# 11      240                           The Godfather Part II
# 12      389                                    12 Angry Men
# 13      424                                Schindler's List
# 14  1218925              Chainsaw Man - The Movie: Reze Arc
# ...

# %%
df.head()
# Out:
#         id                                           title  \
# 0  1560520           Batman: Knightfall Part 1: Knightfall
# 1   980431                 Avatar Aang: The Last Airbender
# 2  1007757                                         Swapped
# 3  1632181                             Accidental Partners
# 4  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
#
#                                             overview release_date
# 0  Arkham Asylum has been destroyed, and all its ...   2026-06-23
# 1  Avatar Aang, the world's last Airbender, learn...   2026-07-24
# 2  A small woodland creature and a majestic bird,...   2026-05-01
# 3  Two women discover they were both scammed by t...   2026-03-12
# 4  The Demon Slayer Corps are drawn into the Infi...   2025-07-18

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 562):
    response = requests.get(
        "https://api.themoviedb.org/3/movie/top_rated",
        params={
            "api_key": api_key,
            "language": "en-US",
            "page": i
        }
    )

    data = response.json()

    temp_df = pd.DataFrame(data['results'])[
        ['id', 'title', 'overview', 'release_date']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_751/3956857824.py in <cell line: 0>()
#      11     data = response.json()
#      12
# ---> 13     temp_df = pd.DataFrame(data['results'])[
#      14         ['id', 'title', 'overview', 'release_date']
#      15     ]
#
# KeyError: 'results'
